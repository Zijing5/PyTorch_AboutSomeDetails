# %%
# %matplotlib inline
import os
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

# %%
d2l.DATA_HUB['hotdog']=(d2l.DATA_URL+'hotdog.zip',
                      'fba480ffa8aa7e0febbb511d181409f899b9baa5')
# URL: dataset file web address
# MD5 hash: a unique checksum value computed from the contents of the dataset file
## acts as a fingerprint to verify the integrity and authenticity of the downloaded file
#  tuple specifying the URL and MD5 hash of the dataset file
data_dir=d2l.download_extract('hotdog')
#  the directory path where the downloaded and extracted dataset files are stored

train_imgs=torchvision.datasets.ImageFolder(os.path.join(data_dir,'train'))
test_imgs=torchvision.datasets.ImageFolder(os.path.join(data_dir,'test'))
#下载训练集和测试集

# %%
torchvision.datasets.folder.ImageFolder??

# %%
type(train_imgs)
# Out:
# torchvision.datasets.folder.ImageFolder

# %% [markdown]
# - about data access
#     + image, label = train_imgs[index]

# %% [markdown]
# - torchvision.transforms.ToTensor()
#     + transform to convert the PIL.Image.Image object into a tensor,

# %%
hotdogs = [train_imgs[i][0] for i in range(8)]
not_hotdogs = [train_imgs[-i - 1][0] for i in range(8)]
d2l.show_images(hotdogs + not_hotdogs, 2, 8, scale=1.4);

# %%
#规范化
normalize=torchvision.transforms.Normalize(
    [0.485,0.456,0.406],[0.229,0.224,0.225])
# the mean and standard deviation values for RGB, respectively. 
# These values are used for normalization to standardize the image data.

## These values have become a standard for normalizing images 
## in many computer vision tasks and pre-trained models.

# %%
#整理数据
train_augs=torchvision.transforms.Compose([
    torchvision.transforms.RandomResizedCrop(224),#随机剪裁
    torchvision.transforms.RandomHorizontalFlip(),#依概率P=0.5水平翻转
    torchvision.transforms.ToTensor(),
    normalize
])

test_augs = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),#改变大小到256
    torchvision.transforms.CenterCrop(224),#中心裁剪224
    torchvision.transforms.ToTensor(),
    normalize])

# %% [markdown]
# - torchvision.models.resnet18??
# ——>File: c:\programdata\anaconda3\envs\pytorch1_13\lib\site-packages\torchvision\models\resnet.py

# %%
from torchvision.models import resnet18,ResNet18_Weights
weights = ResNet18_Weights.DEFAULT
pretrained_net = resnet18(weights=weights)
pretrained_net.fc
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\WZJ/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Linear(in_features=512, out_features=1000, bias=True)

# %%
# pretrained_net = torchvision.models.resnet18(pretrained=True)#下载预训练的resnet18
# pretrained_net.fc

# %% [markdown]
# - **untimeError: PytorchStreamReader failed reading zip archive: failed finding central directory**
# 第一次下载在保存模型参数时没保存完整就停止了## 有时候在torch.save()进行到一半就停止的情况下也会报这种错误
#  C:\Users\WZJ/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth 删除路径

# %% [markdown]
# - fine-tuning step:
#     + download pretrained model
#     + change net
#     + initialize the changeg part

# %%
finetune_net=torchvision.models.resnet18(pretrained=True)
finetune_net.fc=nn.Linear(finetune_net.fc.in_features,2)#更改全连接层
nn.init.xavier_uniform_(finetune_net.fc.weight)#xavier初始化全连接层
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch1_13\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\pytorch1_13\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Parameter containing:
# tensor([[ 0.0289,  0.0949,  0.0882,  ...,  0.0694,  0.0295,  0.0186],
#         [ 0.0471, -0.0959, -0.1009,  ..., -0.0998,  0.0545, -0.0725]],
#        requires_grad=True)

# %% [markdown]
# - **net.named_parameters()**
# return an iterator over the network's parameters.
# It provides both the name and value of each parameter in the network.
# - **net.parameters()**
# return an iterator over all the parameters of a network.
# It provides access to the parameters of all layers and modules in the network, including the weights and biases

# %%
for i in finetune_net.parameters():
    print(i)
# Out:
# Parameter containing:
# tensor([[[[-1.0419e-02, -6.1356e-03, -1.8098e-03,  ...,  5.6615e-02,
#             1.7083e-02, -1.2694e-02],
#           [ 1.1083e-02,  9.5276e-03, -1.0993e-01,  ..., -2.7124e-01,
#            -1.2907e-01,  3.7424e-03],
#           [-6.9434e-03,  5.9089e-02,  2.9548e-01,  ...,  5.1972e-01,
#             2.5632e-01,  6.3573e-02],
#           ...,
#           [-2.7535e-02,  1.6045e-02,  7.2595e-02,  ..., -3.3285e-01,
#            -4.2058e-01, -2.5781e-01],
#           [ 3.0613e-02,  4.0960e-02,  6.2850e-02,  ...,  4.1384e-01,
#             3.9359e-01,  1.6606e-01],
#           [-1.3736e-02, -3.6746e-03, -2.4084e-02,  ..., -1.5070e-01,
#            -8.2230e-02, -5.7828e-03]],
#
#          [[-1.1397e-02, -2.6619e-02, -3.4641e-02,  ...,  3.2521e-02,
#             6.6221e-04, -2.5743e-02],
#           [ 4.5687e-02,  3.3603e-02, -1.0453e-01,  ..., -3.1253e-01,
#            -1.6051e-01, -1.2826e-03],
# ...

# %% [markdown]
# - **fine_tuning**
# 训练的主要不同：1.优化器分组+针对性优化

# %%
def train_fine_tuning(net,learning_rate,batch_size=127,num_epochs=5,
                     params_group=True):
    train_iter=torch.utils.data.DataLoader(torchvision.datasets.ImageFolder(
    os.path.join(data_dir,'train'),transform=train_augs),batch_size=batch_size,shuffle=True)
    test_iter=torch.utils.data.DataLoader(torchvision.datasets.ImageFolder(
    os.path.join(data_dir,'test'),transform=test_augs),batch_size=batch_size)
    devices=d2l.try_all_gpus()
    loss=nn.CrossEntropyLoss(reduction="none")#交叉熵损失
    if params_group:
    # 是否分组更新参数
        params_1x=[params 
                   for name,params in net.named_parameters()
                   if name not in ["fc.weight","fc.bias"]    ]
        trainer=torch.optim.SGD([{'params':params_1x},
                                {'params':net.fc.parameters(),'lr':learning_rate*10}],
                               lr=learning_rate,weight_decay=0.001)#全连接层的参数更新扩大10倍
    else:
        trainer=torch.optim.SGD(net.parameters(),lr=learning_rate,
                               weight_decay=0.001)
    d2l.train_ch13(net,train_iter,test_iter,loss,trainer,num_epochs,devices)

# %%
train_fine_tuning(finetune_net,5e-5)#学习率5e-5
# Out:
# loss 0.161, train acc 0.946, test acc 0.917
# 56.3 examples/sec on [device(type='cuda', index=0)]

# %% [markdown]
# ### 对比

# %%
scratch_net = torchvision.models.resnet18()
scratch_net.fc = nn.Linear(scratch_net.fc.in_features, 2)
train_fine_tuning(scratch_net, 5e-4, param_group=False)#不学习参数

# %%
# 提取对应标签的参数

# %%
for param in finetune_net.parameters():
    param.requires_grad = False
# prevent modifying the pre-trained weights during fine-tuning.
weight = pretrained_net.fc.weight
hotdog_w = torch.split(weight.data, 1, dim=0)[713]  
# index 713 represents the class/type/label exactly desired
# 沿着0维，切割成smaller tensors，每一个smaller tensor 代表初始Tensor的一行
hotdog_w.shape
# Out:
# torch.Size([1, 512])
